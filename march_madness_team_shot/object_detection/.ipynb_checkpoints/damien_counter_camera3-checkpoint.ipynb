# %% [markdown]
# # Object Detection Demo
# Welcome to the object detection inference walkthrough!  This notebook will walk you step by step through the process of using a pre-trained model to detect objects in an image. Make sure to follow the [installation instructions](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/installation.md) before you start.

# %% [markdown]
# # Imports

# %%
from __future__ import division  
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image
import glob
import timeit
import cv2
from datetime import timedelta

# %% [markdown]
# ## Env setup

# %%
# This is needed to display the images.
# %matplotlib inline

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")

# %% [markdown]
# ## Object detection imports
# Here are the imports from the object detection module.

# %%
from utils import label_map_util

from utils import visualization_utils as vis_util

# %% [markdown]
# # Model preparation

# %% [markdown]
# ## Download Model

# %%
# What model to download.

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = '/home/priya/Documents/AI_Apps/damien_counter/model' + '/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('data', 'mscoco_label_map.pbtxt')

NUM_CLASSES = 90

# %% [markdown]
# ## Load a (frozen) Tensorflow model into memory.

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
  od_graph_def = tf.GraphDef()
  with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')

# %% [markdown]
# ## Loading label map
# Label maps map indices to category names, so that when our convolution network predicts `5`, we know that this corresponds to `airplane`.  Here we use internal utility functions, but anything that returns a dictionary mapping integers to appropriate string labels would be fine

# %%
label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

# %% [markdown]
# ## Helper code

# %%
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# # Detection

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip

# %%
from collections import namedtuple
Rectangle = namedtuple('Rectangle', 'xmin ymin xmax ymax')

# ra = Rectangle(3., 3., 5., 5.)
# rb = Rectangle(1., 1., 4., 3.5)
# # intersection here is (3, 3, 4, 3.5), or an area of 1*.5=.5

def area(a, b):  # returns None if rectangles don't intersect
    dx = min(a.xmax, b.xmax) - max(a.xmin, b.xmin)
    dy = min(a.ymax, b.ymax) - max(a.ymin, b.ymin)
    area_a = abs(a.xmax - a.xmin)* abs(a.ymax - a.ymin)
    if (dx>=0) and (dy>=0):
        return dx*dy/area_a

# %%
def detect_videos(image_np, sess, detection_graph):
    
    global total_humans, fps, counter, person_timer, no_person_timer, already_counted
    
    orig_image = image_np

    
    image_np = image_np[30:300, 50:370,:]
#     print(image_np.shape)
    w, h, _ = image_np.shape
#     print(w,h)
    
    fac = 3
    with detection_graph.as_default():
        if counter%fac ==0:

            ops = tf.get_default_graph().get_operations()


            all_tensor_names = {output.name for op in ops for output in op.outputs}

            tensor_dict = {}

            for key in ['num_detections', 'detection_boxes', 'detection_scores',
                            'detection_classes', 'detection_masks']:

                tensor_name = key + ':0'

                if tensor_name in all_tensor_names:

                    tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(tensor_name)

            if 'detection_masks' in tensor_dict:

                # The following processing is only for single image
                detection_boxes = tf.squeeze(tensor_dict['detection_boxes'], [0])
                detection_masks = tf.squeeze(tensor_dict['detection_masks'], [0])

                # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
                real_num_detection = tf.cast(tensor_dict['num_detections'][0], tf.int32)


                detection_boxes = tf.slice(detection_boxes, [0, 0], [real_num_detection, -1])

                detection_masks = tf.slice(detection_masks, [0, 0, 0], [real_num_detection, -1, -1])


                detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                    detection_masks, detection_boxes, image_np.shape[0], image_np.shape[1])

                detection_masks_reframed = tf.cast(
                    tf.greater(detection_masks_reframed, 0.4), tf.uint8)

                # Follow the convention by adding back the batch dimension
                tensor_dict['detection_masks'] = tf.expand_dims(
                    detection_masks_reframed, 0)


            image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

          # Run inference
            output_dict = sess.run(tensor_dict,
                                 feed_dict={image_tensor: np.expand_dims(image_np, 0)})

          # all outputs are float32 numpy arrays, so convert types as appropriate
            output_dict['num_detections'] = int(output_dict['num_detections'][0])


            output_dict['detection_classes'] = output_dict[
                                        'detection_classes'][0][0:5].astype(np.uint8)

            output_dict['detection_boxes'] = output_dict['detection_boxes'][0][0:5]
            
            for i, bbox in enumerate(output_dict['detection_boxes']):
                
                output_dict['detection_boxes'][i] = [int(bbox[0] * h), int(bbox[1] * w), int(bbox[2] * h), int(bbox[3] * w)]
            
            
        #     if counter%90==0: 
            print('Frame No. = ', counter)
        #         print('Output Coordinates = ', output_dict['detection_boxes'])

            output_dict['detection_scores'] = output_dict['detection_scores'][0][0:5]
#             print(output_dict['detection_scores'])

            if 'detection_masks' in output_dict:

                output_dict['detection_masks'] = output_dict['detection_masks'][0][0:5]

#             print(output_dict)

            vis_util.visualize_boxes_and_labels_on_image_array(
                                  orig_image,
                                  output_dict['detection_boxes'],
                                  output_dict['detection_classes'],
                                  output_dict['detection_scores'],
                                  category_index,
                                  instance_masks=output_dict.get('detection_masks'),
#                                   use_normalized_coordinates=True,
                                  line_thickness=2)

#             for n, object in enumerate(output_dict['detection_classes']):
            ## draw rectangle on the image
            ## chosen box is from left top coord 30,30 to bottom right coord : 200, 200
            #uncomment line below to see the box on the frame
#             cv2.rectangle(image_np,(90,90),(200,200),(0,255,0),3)
            
            ## If I detect a human       
            if output_dict['detection_classes'][0]== 1 and output_dict['detection_scores'][0]> 0.40 and counter > 0:
                
                ## Is atleast some portion of the human in this box
                ymin = int(output_dict['detection_boxes'][0][0])
                xmin = int(output_dict['detection_boxes'][0][1])
                ymax = int(output_dict['detection_boxes'][0][2])
                xmax = int(output_dict['detection_boxes'][0][3])
                
                print("Human coords are: ", xmin, ymin, xmax, ymax)

                # calculate overlap b/w 2 rectanges
                rBox = Rectangle(90,90,200,200)
                rHuman = Rectangle(xmin,ymin, xmax,ymax)
                print("Overlap is: ", area(rBox, rHuman))
                
                if area(rBox, rHuman) > 0.4:
                    ## Human is present. Let them be there for long enough time 
                 
                    person_timer += fac
                    
                    
                    if person_timer > fac*13 and already_counted == False:
                        # register as human 
                        already_counted = True
                        total_humans += 1
                    
                    no_person_timer = 0
                        
                else:
                    #reset our counters
                    no_person_timer += fac
                    
                    if no_person_timer > 6*fac:
                        person_timer = 0
                        already_counted = False
            
            # if no human detected reset my counters
            elif counter > 0:
                no_person_timer += fac
                
                if no_person_timer > 6*fac:
                    person_timer = 0
                    already_counted = False
                    

            print('Total humans: ', total_humans)
            print('person_timer: ',person_timer)
            print('no_person_timer: ',no_person_timer)
            print("already counted:", already_counted )
    
                
    text_pos = "No. of persons: " + str(total_humans)
    cv2.putText(orig_image, text_pos, (10, 20), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 255), 1) # Text in red
    
#     cv2.putText(image_np, '{}'.format(counter), (10, 60), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 255), 1)
    
    timestamp = "Time: {} secs".format(timedelta(seconds=(counter / fps)))
    cv2.putText(orig_image, timestamp, (10, 40), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 0, 0), 1) # Text in blue
                
    return orig_image

# %%
def  process_image(image):  
    
    global counter

    
#     if counter%3 ==0:
   
    with detection_graph.as_default():

        with tf.Session(graph=detection_graph) as sess:

            image_np = detect_videos(image, sess, detection_graph) 

    counter +=1 
    
    return image_np

# %%
out_file = 'video_out/camera3_out.mp4'

counter = 0
total_humans = 0
person_timer = 0
no_person_timer = 0
already_counted = False

filename = '/home/priya/Documents/AI_Apps/damien_counter/camera3.avi'
clip1 = VideoFileClip(filename).subclip(0,30)

fps = clip1.fps
print(fps)
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!

# %time white_clip.write_videofile(out_file , audio=False)
# Out:
# 25.0
# ('Frame No. = ', 0)
# ('Total humans: ', 0)
# ('person_timer: ', 0)
# ('no_person_timer: ', 0)
# ('already counted:', False)
# [MoviePy] >>>> Building video video_out/camera3_out.mp4
# [MoviePy] Writing video video_out/camera3_out.mp4
#   0%|          | 0/5001 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|          | 3/5001 [00:00<22:53,  3.64it/s]
# ('Frame No. = ', 3)
# ('Human coords are: ', 72, 3, 217, 246)
# ('Overlap is: ', 1.0)
# ('Total humans: ', 0)
# ('person_timer: ', 3)
# ('no_person_timer: ', 0)
# ('already counted:', False)
#   0%|          | 6/5001 [00:01<22:30,  3.70it/s]
# ('Frame No. = ', 6)
# ('Human coords are: ', 62, 3, 217, 247)
# ('Overlap is: ', 1.0)
# ('Total humans: ', 0)
# ('person_timer: ', 6)
# ('no_person_timer: ', 0)
# ('already counted:', False)
#   0%|          | 9/5001 [00:02<22:41,  3.67it/s]
# ('Frame No. = ', 9)
# ('Human coords are: ', 61, 4, 218, 246)
# ('Overlap is: ', 1.0)
# ('Total humans: ', 0)
# ('person_timer: ', 9)
# ('no_person_timer: ', 0)
# ('already counted:', False)
#

# ('no_person_timer: ', 0)
# ('already counted:', True)
#   9%|▉         | 456/5001 [01:56<18:52,  4.01it/s]
# ('Frame No. = ', 456)
# ('Human coords are: ', 35, 20, 198, 289)
# ('Overlap is: ', 0.9818181818181818)
# ('Total humans: ', 1)
# ('person_timer: ', 453)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#   9%|▉         | 459/5001 [01:57<18:50,  4.02it/s]
# ('Frame No. = ', 459)
# ('Human coords are: ', 36, 25, 198, 293)
# ('Overlap is: ', 0.9818181818181818)
# ('Total humans: ', 1)
# ('person_timer: ', 456)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#   9%|▉         | 462/5001 [01:57<18:52,  4.01it/s]
# ('Frame No. = ', 462)
# ('Human coords are: ', 32, 26, 185, 299)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 1)
# ('person_timer: ', 459)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#   9%|▉         | 465/5001 [01:58<18:50,  4.01it/s]
# ('Frame No. = ', 465)
# ('Human coords are: ', 32, 26, 185, 299)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 1)
# ('person_timer: ', 462)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#   9%|▉         | 468/5001 [01:59<18:52,  4.00it/s]
# ('Frame No. = ', 468)
# ('Human coords are: ', 34, 28, 181, 294)
# ('Overlap is: ', 0.8272727272727273)
# ('Total humans: ', 1)
# ('person_timer: ', 465)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#   9%|▉         | 471/5001 [02:00<18:53,  4.00it/s]
# ('Frame No. = ', 471)
# ('Human coords are: ', 26, 29, 182, 302)
# ('Overlap is: ', 0.8363636363636363)
# ('Total humans: ', 1)
# ('person_timer: ', 468)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#   9%|▉         | 474/5001 [02:00<18:52,  4.00it/s]
# ('Frame No. = ', 474)
# ('Human coords are: ', 26, 29, 182, 302)
# ('Overlap is: ', 0.8363636363636363)
# ('Total humans: ', 1)
# ('person_timer: ', 471)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  10%|▉         | 477/5001 [02:01<18:51,  4.00it/s]
# ('Frame No. = ', 477)
# ('Human coords are: ', 19, 35, 184, 301)
# ('Overlap is: ', 0.8545454545454545)
# ('Total humans: ', 1)
# ('person_timer: ', 474)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  10%|▉         | 480/5001 [02:02<18:52,  3.99it/s]
# ('Frame No. = ', 480)
# ('Human coords are: ', 20, 28, 201, 303)
# ('Overlap is: ', 1.0)
# ('Total humans: ', 1)
# ('person_timer: ', 477)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  10%|▉         | 483/5001 [02:03<18:54,  3.98it/s]
# ('Frame No. = ', 483)
# ('Human coords are: ', 23, 7, 201, 318)
# ('Overlap is: ', 1.0)
# ('Total humans: ', 1)
# ('person_timer: ', 480)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  10%|▉         | 486/5001 [02:03<18:57,  3.97it/s]
# ('Frame No. = ', 486)
# ('Human coords are: ', 23, 7, 201, 318)
# ('Overlap is: ', 1.0)
# ('Total humans: ', 1)
# ('person_timer: ', 483)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  10%|▉         | 489/5001 [02:04<18:52,  3.98it/s]
# ('Frame No. = ', 489)
# ('Human coords are: ', 14, 30, 193, 314)
# ('Overlap is: ', 0.9363636363636364)
# ('Total humans: ', 1)
# ('person_timer: ', 486)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  10%|▉         | 492/5001 [02:05<18:47,  4.00it/s]
# ('Frame No. = ', 492)
# ('Human coords are: ', 18, 29, 197, 313)
# ('Overlap is: ', 0.9727272727272728)
# ('Total humans: ', 1)
# ('person_timer: ', 489)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  10%|▉         | 495/5001 [02:06<18:48,  3.99it/s]
# ('Frame No. = ', 495)
# ('Human coords are: ', 21, 29, 192, 310)
# ('Overlap is: ', 0.9272727272727272)
# ('Total humans: ', 1)
# ('person_timer: ', 492)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  10%

# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▊| 4935/5001 [20:46<00:16,  3.94it/s]
# ('Frame No. = ', 4935)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3669)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▊| 4938/5001 [20:47<00:15,  3.95it/s]
# ('Frame No. = ', 4938)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3672)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4941/5001 [20:48<00:15,  3.93it/s]
# ('Frame No. = ', 4941)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3675)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4944/5001 [20:49<00:14,  3.94it/s]
# ('Frame No. = ', 4944)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3678)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4947/5001 [20:49<00:13,  3.96it/s]
# ('Frame No. = ', 4947)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3681)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4950/5001 [20:50<00:12,  3.95it/s]
# ('Frame No. = ', 4950)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3684)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4953/5001 [20:51<00:12,  3.96it/s]
# ('Frame No. = ', 4953)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3687)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4956/5001 [20:52<00:11,  3.95it/s]
# ('Frame No. = ', 4956)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3690)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4959/5001 [20:52<00:10,  3.94it/s]
# ('Frame No. = ', 4959)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3693)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4962/5001 [20:53<00:09,  3.96it/s]
# ('Frame No. = ', 4962)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3696)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4965/5001 [20:54<00:09,  3.96it/s]
# ('Frame No. = ', 4965)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3699)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4968/5001 [20:55<00:08,  3.98it/s]
# ('Frame No. = ', 4968)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3702)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4971/5001 [20:55<00:07,  3.99it/s]
# ('Frame No. = ', 4971)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3705)
# ('no_person_timer: ', 0)
# ('already counted:', True)
#  99%|█████████▉| 4974/5001 [20:56<00:06,  4.00it/s]
# ('Frame No. = ', 4974)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3708)
# ('no_person_timer: ', 0)
# ('already counted:', True)
# 100%|█████████▉| 4977/5001 [20:57<00:05,  4.00it/s]
# ('Frame No. = ', 4977)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3711)
# ('no_person_timer: ', 0)
# ('already counted:', True)
# 100%|█████████▉| 4980/5001 [20:58<00:05,  4.00it/s]
# ('Frame No. = ', 4980)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3714)
# ('no_person_timer: ', 0)
# ('already counted:', True)
# 100%|█████████▉| 4983/5001 [20:58<00:04,  3.97it/s]
# ('Frame No. = ', 4983)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3717)
# ('no_person_timer: ', 0)
# ('already counted:', True)
# 100%|█████████▉| 4986/5001 [20:59<00:03,  3.95it/s]
# ('Frame No. = ', 4986)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3720)
# ('no_person_timer: ', 0)
# ('already counted:', True)
# 100%|█████████▉| 4989/5001 [21:00<00:03,  3.96it/s]
# ('Frame No. = ', 4989)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3723)
# ('no_person_timer: ', 0)
# ('already counted:', True)
# 100%|█████████▉| 4992/5001 [21:01<00:02,  3.90it/s]
# ('Frame No. = ', 4992)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3726)
# ('no_person_timer: ', 0)
# ('already counted:', True)
# 100%|█████████▉| 4995/5001 [21:01<00:01,  3.93it/s]
# ('Frame No. = ', 4995)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3729)
# ('no_person_timer: ', 0)
# ('already counted:', True)
# 100%|█████████▉| 4998/5001 [21:02<00:00,  3.91it/s]
#
#
#
#
#
# 100%|█████████▉| 5000/5001 [21:02<00:00,  3.96it/s]
# ('Frame No. = ', 4998)
# ('Human coords are: ', 34, 5, 185, 235)
# ('Overlap is: ', 0.8636363636363636)
# ('Total humans: ', 2)
# ('person_timer: ', 3732)
# ('no_person_timer: ', 0)
# ('already counted:', True)
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: video_out/camera3_out.mp4
#
# CPU times: user 21min 55s, sys: 35 s, total: 22min 30s
# Wall time: 21min 2s
